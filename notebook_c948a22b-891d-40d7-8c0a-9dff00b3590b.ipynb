# %%
# Handling missing values
df = pd.DataFrame(load_session('c948a22b-891d-40d7-8c0a-9dff00b3590b')['modified'])
df_cleaned = df.dropna(subset=['Ambedkar Nagar'])

# %%
# Handling missing values
df = pd.DataFrame(load_session('c948a22b-891d-40d7-8c0a-9dff00b3590b')['modified'])
df_cleaned['Ambedkar Nagar'] = df['Ambedkar Nagar'].fillna(df['Ambedkar Nagar'].mean(numeric_only=True))
